# %%
import findspark
findspark.init('/usr/local/spark')
import pyspark
sc = pyspark.SparkContext(appName = "word count")

# %%
lines = sc.textFile("/home/hduser/Downloads/sharedfolder/war_and_peace.txt",2)

# %%
lines.count()
# Out:
# 63877

# %%
lines.getNumPartitions()
# Out:
# 2

# %%
def count_in_partitions(iterator):
    yield sum(1 for _ in iterator)
lines.mapPartitions(count_in_partitions).collect()
# Out:
# [32385, 31492]

# %%
lines.count()
# Out:
# 63877

# %%
nonullcount = lines.filter(lambda x : len(x) >0)

# %%
nonullcount.count()
# Out:
# 50902

# %%
lines.head(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-bd61aca5608b> in <module>
# ----> 1 lines.head(1)
#
# AttributeError: 'RDD' object has no attribute 'head'

# %%
lines.take(5)
# Out:
# ['The Project Gutenberg EBook of War and Peace, by Leo Tolstoy',
#  '',
#  'This eBook is for the use of anyone anywhere at no cost and with almost',
#  'no restrictions whatsoever.  You may copy it, give it away or re-use it',
#  'under the terms of the Project Gutenberg License included with this']

# %%
lines.top(5)
# Out:
# ['zero, we should even then not have arrived at the conception of complete',
#  "zealous champion of old of our country's weal, is offered to Your",
#  'youths, officers and cadets, who had galloped past him on their',
#  'youthfully glittering eyes.',
#  'youthful movement, stood for a moment in the stirrup as if loathe to']

# %%
linesfmap = lines.flatMap(lambda x: x.split(" "))f
# Out:
#   File "<ipython-input-30-f2ea64014a12>", line 1
#     linesfmap = lines.flatMap(lambda x: x.split(" "))f
#                                                      ^
# SyntaxError: invalid syntax

# %%
linesmap.collect()
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'War',
#  'and',
#  'Peace,',
#  'by',
#  'Leo',
#  'Tolstoy',
#  '',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  '',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '',
#  '',
#  'Title:',
#  'War',
#  'and',
#  'Peace',
#  '',
#  'Author:',
#  'Leo',
#  'Tolstoy',
#  '',
#  'Translators:',
#  'Louise',
#  'and',
#  'Aylmer',
#  'Maude',
#  '',
#  'Posting',
#  'Date:',
#  'January',
#  '10,',
#  '2009',
#  '[EBook',
#  '#2600]',
#  '',
#  'Last',
#  'Updated:',
#  'March',
#  '15,',
#  '2013',
#  '',
# ...

# %%
linesmap = linesfmap.map(lambda x: (x,1))

# %%
linesmap.collect()
# Out:
# [('The', 1),
#  ('Project', 1),
#  ('Gutenberg', 1),
#  ('EBook', 1),
#  ('of', 1),
#  ('War', 1),
#  ('and', 1),
#  ('Peace,', 1),
#  ('by', 1),
#  ('Leo', 1),
#  ('Tolstoy', 1),
#  ('', 1),
#  ('This', 1),
#  ('eBook', 1),
#  ('is', 1),
#  ('for', 1),
#  ('the', 1),
#  ('use', 1),
#  ('of', 1),
#  ('anyone', 1),
#  ('anywhere', 1),
#  ('at', 1),
#  ('no', 1),
#  ('cost', 1),
#  ('and', 1),
#  ('with', 1),
#  ('almost', 1),
#  ('no', 1),
#  ('restrictions', 1),
#  ('whatsoever.', 1),
#  ('', 1),
#  ('You', 1),
#  ('may', 1),
#  ('copy', 1),
#  ('it,', 1),
#  ('give', 1),
#  ('it', 1),
#  ('away', 1),
#  ('or', 1),
#  ('re-use', 1),
#  ('it', 1),
#  ('under', 1),
#  ('the', 1),
#  ('terms', 1),
#  ('of', 1),
#  ('the', 1),
#  ('Project', 1),
#  ('Gutenberg', 1),
#  ('License', 1),
#  ('included', 1),
#  ('with', 1),
#  ('this', 1),
#  ('eBook', 1),
#  ('or', 1),
#  ('online', 1),
#  ('at', 1),
#  ('www.gutenberg.org', 1),
#  ('', 1),
#  ('', 1),
#  ('Title:', 1),
#  ('War', 1),
# ...

# %%
wordcount = linesmap.reduceByKey(lambda a,b: (a+b))

# %%
wordcount.collect()
# Out:
# [('', 13067),
#  ('century)', 1),
#  ('reminiscence', 1),
#  ('matrimonial', 1),
#  ('Empereur.', 1),
#  ('sea.', 1),
#  ('circle', 34),
#  ('detail:', 1),
#  ('brigade--gave', 1),
#  ('wings', 2),
#  ('rustle,', 1),
#  ('Moscow?"', 8),
#  ('kiss,', 3),
#  ('Whole,"', 1),
#  ('something?"', 1),
#  ('prisoners--was', 1),
#  ('neighing', 1),
#  ('spoken', 46),
#  ('body--it', 1),
#  ('belt', 4),
#  ('twice,', 2),
#  ('baked,', 1),
#  ('escape,', 3),
#  ('thighs', 1),
#  ('outright.', 1),
#  ('bantering', 2),
#  ('embarrassment', 10),
#  ('whole?', 1),
#  ('rusty', 1),
#  ('attack."', 2),
#  ('accordingly."', 1),
#  ('why', 217),
#  ('shallow', 2),
#  ('re-enter', 2),
#  ('Bolkonski,', 37),
#  ('Just', 74),
#  ('preceding', 10),
#  ('cookers.', 1),
#  ('French),', 1),
#  ('passe', 1),
#  ('Aunt..."', 2),
#  ("XIV's", 1),
#  ('intense.', 1),
#  ('frightfully', 1),
#  ('Fedeshon!...', 1),
#  ('spectators.', 1),
#  ('grapeshot?"', 1),
#  ('Antonovna', 1),
#  ('alert,', 3),
# ...
